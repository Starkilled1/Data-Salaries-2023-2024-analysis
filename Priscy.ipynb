# %% [markdown]
# ## Dataset by company size
# **What do companies tend to look for in relation to their size?**

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt

#Lecture
path = 'DataScience_salaries_2024.csv'
salaries_df = pd.read_csv(path)
salaries_df.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L
# 2               HU            L
# 3               JP            S
# 4               IN            L

# %%
#Copy the original dataframe into a new variable
companysizedf=salaries_df.copy()

# %% [markdown]
# # Separate the company by sizes
# **Rows by company size**

# %%
#Filter the rows 'company size' of the dataset (Small)
smallcompanydf=companysizedf[companysizedf['company_size']=='S']
smallcompanydf
# Out:
#        work_year experience_level employment_type  \
# 3           2021               MI              FT
# 5           2021               MI              FT
# 11          2023               EN              FT
# 14          2020               EN              FT
# 31          2022               MI              FL
# ...          ...              ...             ...
# 14819       2021               EN              FT
# 14822       2020               EN              PT
# 14823       2023               EN              FT
# 14826       2021               MI              FT
# 14837       2020               EN              PT
#
#                                 job_title   salary salary_currency  \
# 3                             ML Engineer  8500000             JPY
# 5                             ML Engineer  7000000             JPY
# 11                          AI Programmer  4950806             INR
# 14                          Data Engineer  4450000             JPY
# 31     Applied Machine Learning Scientist  2400000             INR
# ...                                   ...      ...             ...
# 14819           Machine Learning Engineer    20000             USD
# 14822                      Data Scientist    19000             EUR
# 14823                   Data Analyst Lead    18000             USD
# 14826                   Big Data Engineer    18000             USD
# 14837                         ML Engineer    14000             EUR
#
#        salary_in_usd employee_residence  remote_ratio company_location  \
# 3              77364                 JP            50               JP
# 5              63711                 JP            50               JP
# 11             60207                 IN             0               IN
# 14             41689                 JP           100               JP
# 31             30523                 IN           100               IN
# ...              ...                ...           ...              ...
# 14819          20000                 IN           100               IN
# 14822          21669                 IT            50               IT
# 14823          18000                 NG           100               NG
# 14826          18000                 MD             0               MD
# 14837          15966                 DE           100               DE
#
#       company_size
# 3                S
# 5                S
# 11               S
# 14               S
# 31               S
# ...            ...
# 14819            S
# 14822            S
# 14823            S
# 14826            S
# 14837            S
#
# [181 rows x 11 columns]

# %%
#Filter the rows 'company size' of the dataset (Medium)
mediumcompanydf=companysizedf[companysizedf['company_size']=='M']
mediumcompanydf
# Out:
#        work_year experience_level employment_type  \
# 7           2022               EN              FT
# 22          2023               MI              FT
# 28          2023               MI              FT
# 29          2022               MI              FT
# 30          2021               MI              FT
# ...          ...              ...             ...
# 14825       2023               EN              FT
# 14831       2022               EN              FT
# 14832       2024               EN              PT
# 14833       2022               MI              FT
# 14834       2020               EX              FT
#
#                              job_title   salary salary_currency  \
# 7                       Data Scientist  6600000             HUF
# 22              Data Analytics Manager  3200000             INR
# 28                        NLP Engineer  2700000             INR
# 29                      Data Scientist  2500000             INR
# 30                      Data Scientist  2500000             INR
# ...                                ...      ...             ...
# 14825                    Data Engineer    18000             USD
# 14831                Research Engineer    15662             EUR
# 14832                     Data Science    15000             EUR
# 14833  Business Intelligence Developer    15000             USD
# 14834               Staff Data Analyst    15000             USD
#
#        salary_in_usd employee_residence  remote_ratio company_location  \
# 7              17684                 HU           100               HU
# 22             38915                 IN            50               IN
# 28             32834                 IN           100               IN
# 29             31795                 IN           100               US
# 30             33808                 IN             0               IN
# ...              ...                ...           ...              ...
# 14825          18000                 IN            50               IN
# 14831          16455                 RU           100               RU
# 14832          16666                 DE            50               DE
# 14833          15000                 GH           100               GH
# 14834          15000                 NG             0               CA
#
#       company_size
# 7                M
# 22               M
# 28               M
# 29               M
# 30               M
# ...            ...
# 14825            M
# 14831            M
# 14832            M
# 14833            M
# 14834            M
#
# [13674 rows x 11 columns]

# %%
#Filter the rows 'company size' of the dataset (Large)
largecompanydf=companysizedf[companysizedf['company_size']=='L']
largecompanydf
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 4           2022               SE              FT
# 6           2021               SE              FT
# ...          ...              ...             ...
# 14828       2024               EN              FT
# 14829       2023               MI              FT
# 14830       2023               EN              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
#
#                             job_title    salary salary_currency  \
# 0                      Data Scientist  30400000             CLP
# 1                     BI Data Analyst  11000000             HUF
# 2                      Data Scientist  11000000             HUF
# 4      Lead Machine Learning Engineer   7500000             INR
# 6                Data Science Manager   7000000             INR
# ...                               ...       ...             ...
# 14828                   Data Engineer     17598             USD
# 14829           Business Data Analyst     17000             USD
# 14830                  Data Scientist     16000             USD
# 14835      Machine Learning Developer     15000             USD
# 14836                    Data Analyst     15000             USD
#
#        salary_in_usd employee_residence  remote_ratio company_location  \
# 0              40038                 CL           100               CL
# 1              36259                 HU            50               US
# 2              35735                 HU            50               HU
# 4              95386                 IN            50               IN
# 6              94665                 IN            50               IN
# ...              ...                ...           ...              ...
# 14828          17598                 MX            50               MX
# 14829          17000                 AM           100               RU
# 14830          16000                 EC           100               EC
# 14835          15000                 TH           100               TH
# 14836          15000                 ID             0               ID
#
#       company_size
# 0                L
# 1                L
# 2                L
# 4                L
# 6                L
# ...            ...
# 14828            L
# 14829            L
# 14830            L
# 14835            L
# 14836            L
#
# [983 rows x 11 columns]

# %% [markdown]
# # Filter according to the job position.
# **Jobs requesting more according to size**

# %%
smallcompanydf.value_counts('job_title')
# Out:
# job_title
# Data Scientist                        31
# Machine Learning Engineer             22
# Data Analyst                          19
# ML Engineer                            9
# Data Engineer                          9
# Machine Learning Scientist             8
# AI Scientist                           7
# AI Developer                           4
# BI Data Analyst                        4
# Data Science Consultant                4
# Computer Vision Engineer               4
# Lead Data Engineer                     4
# Research Scientist                     4
# Lead Data Scientist                    3
# AI Programmer                          3
# Big Data Engineer                      3
# Research Engineer                      3
# Machine Learning Researcher            2
# Machine Learning Developer             2
# NLP Engineer                           2
# Computer Vision Software Engineer      2
# Product Data Analyst                   2
# Data Analyst Lead                      2
# Analytics Engineer                     2
# Lead Machine Learning Engineer         1
# Principal Data Analyst                 1
# Research Analyst                       1
# Prompt Engineer                        1
# Principal Data Scientist               1
# Head of Data Science                   1
# Marketing Data Analyst                 1
# Data Science Engineer                  1
# Head of Data                           1
# Finance Data Analyst                   1
# AI Research Engineer                   1
# Applied Data Scientist                 1
# Applied Machine Learning Engineer      1
# Applied Machine Learning Scientist     1
# Applied Research Scientist             1
# Azure Data Engineer                    1
# BI Analyst                             1
# Business Data Analyst                  1
# Cloud Data Engineer                    1
# Data Analytics Consultant              1
# Data DevOps Engineer                   1
# Data Manager                           1
# AI Engineer                            1
# Data Science Lead                      1
# Director of Data Science               1
# Staff Data Analyst                     1
# Name: count, dtype: int64

# %%
mediumcompanydf.value_counts('job_title')
# Out:
# job_title
# Data Engineer                        3033
# Data Scientist                       2849
# Data Analyst                         2122
# Machine Learning Engineer            1466
# Research Scientist                    421
#                                      ...
# Sales Data Analyst                      1
# Software Data Engineer                  1
# Staff Data Analyst                      1
# Computer Vision Software Engineer       1
# Staff Machine Learning Engineer         1
# Name: count, Length: 126, dtype: int64

# %%
largecompanydf.value_counts('job_title')
# Out:
# job_title
# Applied Scientist                 223
# Data Scientist                    135
# Data Engineer                     120
# Business Intelligence Engineer     98
# Machine Learning Engineer          54
#                                  ...
# Head of Machine Learning            1
# Data Analytics Associate            1
# Azure Data Engineer                 1
# Analytics Engineering Manager       1
# Staff Data Analyst                  1
# Name: count, Length: 95, dtype: int64

# %% [markdown]
# # Charting company sizes according to job position
# ****
# *The best way to display the results (according to us) is to show it in a pie chart for each size*

# %%
#Create a new variable to generate the graphs(Small)
count_small_companies=smallcompanydf.value_counts('job_title')
small_job_titles=smallcompanydf['job_title'].unique()
plt.pie(count_small_companies,labels=small_job_titles,autopct='%1.1f%%')
plt.title('Small Companies - Job Title')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Create a new variable to generate the graphs(Medium)
count_medium_companies=mediumcompanydf.value_counts('job_title')
medium_job_titles=mediumcompanydf['job_title'].unique()
plt.pie(count_medium_companies,labels=medium_job_titles,autopct='%1.1f%%')
plt.title('Medium Companies - Job Title')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Create a new variable to generate the graphs(Large)
count_large_companies=largecompanydf.value_counts('job_title')
large_job_titles=largecompanydf['job_title'].unique()
plt.pie(count_large_companies,labels=large_job_titles,autopct='%1.1f%%')
plt.title('Large Companies - Job Title')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## cuál es la distribución de niveles de experiencia entre los diferentes entries? Para sacar otra gráfica de cuantos jobs son de cada nivel de experiencia

# %% [markdown]
# # Separate the experience by levels
# **Rows by experience levels**

# %%
#Copy the original dataframe into a new variable
experienceleveldf=salaries_df.copy()

# %%
#Filter the rows 'Experience Level' of the dataset (MI)
smallcompanydf=companysizedf[companysizedf['experience_level']=='MI']
smallcompanydf
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 5           2021               MI              FT
# ...          ...              ...             ...
# 14817       2020               MI              FT
# 14821       2021               MI              FL
# 14826       2021               MI              FT
# 14829       2023               MI              FT
# 14833       2022               MI              FT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# 5                          ML Engineer   7000000             JPY
# ...                                ...       ...             ...
# 14817             Product Data Analyst     20000             USD
# 14821                    Data Engineer     20000             USD
# 14826                Big Data Engineer     18000             USD
# 14829            Business Data Analyst     17000             USD
# 14833  Business Intelligence Developer     15000             USD
#
#        salary_in_usd employee_residence  remote_ratio company_location  \
# 0              40038                 CL           100               CL
# 1              36259                 HU            50               US
# 2              35735                 HU            50               HU
# 3              77364                 JP            50               JP
# 5              63711                 JP            50               JP
# ...              ...                ...           ...              ...
# 14817          20000                 HN             0               HN
# 14821          20000                 IT             0               US
# 14826          18000                 MD             0               MD
# 14829          17000                 AM           100               RU
# 14833          15000                 GH           100               GH
#
#       company_size
# 0                L
# 1                L
# 2                L
# 3                S
# 5                S
# ...            ...
# 14817            S
# 14821            L
# 14826            S
# 14829            L
# 14833            M
#
# [3553 rows x 11 columns]

# %% [markdown]
# # Filter data according to your experience
# **Show what levels of experience are required by companies according to their size**

# %%
experienceleveldf=salaries_df.copy()
